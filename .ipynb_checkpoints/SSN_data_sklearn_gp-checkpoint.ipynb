# %% [markdown]
# # Fit a GP to SSN number using an sklearn GP
#
# This is a leanring experiment, to demonstrate (quickly!?!) the basics of a GP.

# %%
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Read in the data

# %%
data_file = 'data/SSN/sunspot_data.csv'
df = pd.read_csv(data_file)
print(len(df))
df.head()
# Out:
# 73718
#    Unnamed: 0  Year  Month  Day  Date In Fraction Of Year  Number of Sunspots  \
# 0           0  1818      1    1                  1818.001                  -1
# 1           1  1818      1    2                  1818.004                  -1
# 2           2  1818      1    3                  1818.007                  -1
# 3           3  1818      1    4                  1818.010                  -1
# 4           4  1818      1    5                  1818.012                  -1
#
#    Standard Deviation  Observations  Indicator
# 0                -1.0             0          1
# 1                -1.0             0          1
# 2                -1.0             0          1
# 3                -1.0             0          1
# 4                -1.0             0          1

# %% [markdown]
# ### Remove data with SSN = 0 or -1

# %%
print(len(df))
df = df[df['Number of Sunspots'] > 0]
print(len(df))
# Out:
# 73718
# 59370

# %%
fig, ax = plt.subplots(dpi=300)
ax.scatter(df['Date In Fraction Of Year'].values, 
           df['Number of Sunspots'], 
          s=1./2)

# %%
df_small = df.sample(frac=0.04, ignore_index=True)
df_small = df_small[df_small['Date In Fraction Of Year'] < 1950.]
print(len(df_small))
# Out:
# 1468

# %%
fig, ax = plt.subplots(dpi=300)
ax.scatter(df_small['Date In Fraction Of Year'].values, 
           np.log10(df_small['Number of Sunspots'].values), 
          s=1./2)

# %%
df1 = df[df['Date In Fraction Of Year'] < 1950.]

X = df1['Date In Fraction Of Year'].values[:, np.newaxis]
y = np.log(df1['Number of Sunspots'].values)



from scipy.signal import savgol_filter
yd = savgol_filter(y, 3*365, 4)

X = X[::20]
y = yd[::20]

# %%
fig, ax = plt.subplots(dpi = 300)

ax.scatter(df['Date In Fraction Of Year'].values, 
           np.log(df['Number of Sunspots'].values), 
          s=1./2, c='grey')
ax.scatter(X, y, s=1)

print(len(X), len(y))
# Out:
# 1838 1838

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel
from sklearn.gaussian_process.kernels import ExpSineSquared, RBF

seasonal_kernel = (
    4.0**2
    * RBF(length_scale=300.0,
         length_scale_bounds=[1., 500.], )
    * ExpSineSquared(length_scale=300.0, periodicity=11.0, 
                     length_scale_bounds=[1., 500.], 
                     periodicity_bounds=[10.0, 11.5])
)

qbo_kernel = (
    0.5**2
    * RBF(length_scale=100.0,
         length_scale_bounds=[1., 5000.], )
    * ExpSineSquared(length_scale=100.0, periodicity=2.0, 
                     length_scale_bounds=[1., 1500.], 
                     periodicity_bounds=[1.0, 2.6])
)

long_term_trend_kernel = 1.0**2 * RBF(length_scale=500.0, 
                                      length_scale_bounds=[50., 5000.])



noise_kernel =  WhiteKernel(
    noise_level=0.2**2, noise_level_bounds=[0.01, 0.5]
)

kernel = seasonal_kernel + qbo_kernel + long_term_trend_kernel + noise_kernel

gpr = GaussianProcessRegressor(kernel=kernel,
        random_state=0, normalize_y=False).fit(X, y)

gpr.score(X, y)
# Out:
# /Users/davies/opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:411: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__k1__k1__k2__length_scale is close to the specified upper bound 500.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# /Users/davies/opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:402: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__k1__k2__periodicity is close to the specified lower bound 10.0. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# /Users/davies/opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:411: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__k2__length_scale is close to the specified upper bound 5000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# /Users/davies/opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:402: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# 0.9965886517715774

# %%
X_new = np.linspace(1818, 2020, 1000)[:, np.newaxis]
pred, std = gpr.predict(X_new, return_std=True)

# %%
fig, ax = plt.subplots(dpi=300)
ax.scatter(df_small['Date In Fraction Of Year'].values, 
           np.log(df_small['Number of Sunspots'].values), 
          s=1./2, color='k')
ax.scatter(df['Date In Fraction Of Year'].values, 
           np.log(df['Number of Sunspots'].values), 
          s=1./2, alpha=0.02, color='k')
ax.scatter(X_new, pred, s=1., color='r')
ax.fill_between(X_new[:, 0], (pred+std), (pred-std), color='r', alpha=0.1)
ax.fill_between(X_new[:, 0], (pred+2*std), (pred-2*std), color='r', alpha=0.03)

# %%
gpr.kernel_
# Out:
# 0.578**2 * RBF(length_scale=500) * ExpSineSquared(length_scale=3.32, periodicity=10) + 0.53**2 * RBF(length_scale=1.08) * ExpSineSquared(length_scale=2.11, periodicity=1.35) + 3.81**2 * RBF(length_scale=5e+03) + WhiteKernel(noise_level=0.01)

# %%
fig, ax = plt.subplots(dpi=300)
ax.scatter(df_small['Date In Fraction Of Year'].values, 
           (df_small['Number of Sunspots'].values), 
          s=1./2, color='b')
ax.scatter(df['Date In Fraction Of Year'].values, 
           (df['Number of Sunspots'].values), 
          s=1./2, alpha=0.02, color='k')

X_pred = np.linspace(1950, 2030, 1000)[:, np.newaxis]
for i in range(1):
    y_pred = gpr.sample_y(X_pred, random_state=i)
    ax.plot(X_pred, np.exp(y_pred), alpha=0.9)
